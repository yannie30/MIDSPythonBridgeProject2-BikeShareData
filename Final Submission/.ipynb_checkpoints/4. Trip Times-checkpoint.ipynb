# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # NYC Data

# %%
# Read in NYC data

nyc_data = pd.read_csv('nyc_merged_data.csv', parse_dates = ['starttime', 'stoptime'])
del nyc_data["Unnamed: 0"]
nyc_data["Year Month"] = nyc_data['starttime'].dt.strftime('%Y%m')
nyc_data.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0           634 2013-07-01 00:00:00 2013-07-01 00:10:34               164
# 1          1547 2013-07-01 00:00:02 2013-07-01 00:25:49               388
# 2           178 2013-07-01 00:01:04 2013-07-01 00:04:02               293
# 3          1580 2013-07-01 00:01:06 2013-07-01 00:27:26               531
# 4           757 2013-07-01 00:01:10 2013-07-01 00:13:47               382
#
#         start station name  end station id         end station name  bikeid  \
# 0          E 47 St & 2 Ave             504          1 Ave & E 15 St   16950
# 1         W 26 St & 10 Ave             459         W 20 St & 11 Ave   19816
# 2    Lafayette St & E 8 St             237          E 11 St & 2 Ave   14548
# 3   Forsyth St & Broome St             499       Broadway & W 60 St   16063
# 4  University Pl & E 14 St             410  Suffolk St & Stanton St   19213
#
#      usertype city  weather key  Pecipitation  max temp  min temp  avg wind  \
# 0    Customer  nyc     20130701          0.84        77        72       3.1
# 1    Customer  nyc     20130701          0.84        77        72       3.1
# 2  Subscriber  nyc     20130701          0.84        77        72       3.1
# 3    Customer  nyc     20130701          0.84        77        72       3.1
# 4  Subscriber  nyc     20130701          0.84        77        72       3.1
#
#   Year Month
# 0     201307
# 1     201307
# 2     201307
# 3     201307
# 4     201307

# %%
# Columns for NYC data

list(nyc_data.columns.values)
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'end station id',
#  'end station name',
#  'bikeid',
#  'usertype',
#  'city',
#  'weather key',
#  'Pecipitation',
#  'max temp',
#  'min temp',
#  'avg wind',
#  'Year Month']

# %% [markdown]
# # SF Data

# %%
# Read in SF data

sf_data = pd.read_csv('sf_merged_data.csv', parse_dates = ['starttime', 'stoptime'])
del sf_data["Unnamed: 0"]
sf_data["Year Month"] = sf_data['starttime'].dt.strftime('%Y%m')
sf_data.head()
# Out:
# /Users/andrewlam/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    tripduration           starttime        start station name  \
# 0            63 2013-08-29 14:13:00  South Van Ness at Market
# 1            70 2013-08-29 14:42:00        San Jose City Hall
# 2            71 2013-08-29 10:16:00   Mountain View City Hall
# 3            77 2013-08-29 11:29:00        San Jose City Hall
# 4            83 2013-08-29 12:02:00  South Van Ness at Market
#
#    start station id            stoptime          end station name  \
# 0                66 2013-08-29 14:14:00  South Van Ness at Market
# 1                10 2013-08-29 14:43:00        San Jose City Hall
# 2                27 2013-08-29 10:17:00   Mountain View City Hall
# 3                10 2013-08-29 11:30:00        San Jose City Hall
# 4                66 2013-08-29 12:04:00            Market at 10th
#
#    end station id  bikeid    usertype           city    weather key  max temp  \
# 0              66     520  Subscriber  San Francisco  2013082994107      74.0
# 1              10     661  Subscriber       San Jose  2013082995113      81.0
# 2              27      48  Subscriber  Mountain View  2013082994041      80.0
# 3              10      26  Subscriber       San Jose  2013082995113      81.0
# 4              67     319  Subscriber  San Francisco  2013082994107      74.0
#
#    min temp  avg wind Pecipitation Year Month
# 0      61.0      11.0            0     201308
# 1      63.0       7.0            0     201308
# 2      64.0       5.0            0     201308
# 3      63.0       7.0            0     201308
# 4      61.0      11.0            0     201308

# %%
# Shape of SF data

sf_data.shape
# Out:
# (669959, 16)

# %%
# Columns for SF data

list(sf_data.columns.values)
# Out:
# ['tripduration',
#  'starttime',
#  'start station name',
#  'start station id',
#  'stoptime',
#  'end station name',
#  'end station id',
#  'bikeid',
#  'usertype',
#  'city',
#  'weather key',
#  'max temp',
#  'min temp',
#  'avg wind',
#  'Pecipitation',
#  'Year Month']

# %% [markdown]
# # Trip Times

# %% [markdown]
# What is the average trip time by start/stop station?

# %%
# NY

# Creating a new column to change units from seconds to minutes
nyc_data['tripduration_min'] = nyc_data['tripduration'].map(lambda x: x/60)

# %%
# Average trip time by start station in minutes 
nyc_data.groupby(['start station name'], as_index=False).tripduration_min.mean()
# Out:
#                                  start station name  tripduration_min
# 0                                   1 Ave & E 15 St         12.785604
# 1                                   1 Ave & E 18 St         13.089510
# 2                                   1 Ave & E 30 St         13.530626
# 3                                   1 Ave & E 44 St         15.555993
# 4                                   1 Ave & E 62 St         15.486148
# 5                                   1 Ave & E 68 St         16.991994
# 6                                   1 Ave & E 78 St         19.244034
# 7                                  10 Ave & W 28 St         13.685645
# 8                                  11 Ave & W 27 St         15.452753
# 9                                  11 Ave & W 41 St         15.559211
# 10                                 11 Ave & W 59 St         21.743627
# 11                                 12 Ave & W 40 St         22.940695
# 12                                  2 Ave & E 31 St         13.223420
# 13                                  2 Ave & E 58 St         17.130214
# 14                                   21 St & 41 Ave         27.437577
# 15                                   21 St & 43 Ave         20.312349
# 16                       21 St & Queens Plaza North         25.228158
# 17                                  3 Ave & E 62 St         16.354710
# 18                                  3 Ave & E 71 St         15.834937
# 19                          3 Ave & Schermerhorn St         21.004875
# 20                              31 St & Thomson Ave         24.164974
# 21   3969.TEMP (Bike The Branches - Central Branch)         56.018519
# 22                              44 Dr & Jackson Ave         18.481974
# 23                                    45 Rd & 11 St         17.975014
# 24                                    46 Ave & 5 St         12.943290
# 25                                   47 Ave & 31 St         22.361411
# 26                                    48 Ave & 5 St         25.057044
# 27                                  5 Ave & E 29 St         12.869044
# 28                                  5 Ave & E 63 St         32.166050
# 29                                  5 Ave & E 73 St         28.819109
# ..                                              ...               ...
# 497                              W 67 St & Broadway         17.006001
# 498                         W 70 St & Amsterdam Ave         16.999019
# 499                          W 74 St & Columbus Ave         18.802592
# 500                          W 76 St & Columbus Ave         17.054456
# 501                              W 78 St & Broadway         20.865203
# 502                     W 82 St & Central Park West         23.059072
# 503                              W 84 St & Broadway         23.211276
# 504                          W 84 St & Columbus Ave         20.836527
# 505                          W Broadway & Spring St         16.605464
# 506                        W Houston St & Hudson St         14.684739
# 507                           Warren St & Church St         15.878157
# 508                     Washington Ave & Greene Ave         14.554891
# 509                       Washington Ave & Park Ave         16.455161
# 510                                 Washington Park         12.067044
# 511                           Washington Pl & 6 Ave         13.127344
# 512                        Washington Pl & Broadway         12.674607
# 513                             Washington Square E         11.784782
# 514                   Washington St & Gansevoort St         17.828803
# 515                         Water - Whitehall Plaza         20.687126
# 516                         Watts St & Greenwich St         15.664749
# 517                           West St & Chambers St         20.427999
# 518                                  West Thames St         18.225123
# 519                            William St & Pine St         16.047662
# 520                        Willoughby Ave & Hall St         13.926783
# 521                   Willoughby Ave & Tompkins Ave         14.435241
# 522                    Willoughby Ave & Walworth St         21.506032
# 523                        Willoughby St & Fleet St         11.314644
# 524                    Wythe Ave & Metropolitan Ave         24.237537
# 525                           Yankee Ferry Terminal         43.588169
# 526                                York St & Jay St         18.161541
#
# [527 rows x 2 columns]

# %%
# Histogram of NYC Trip Durations

nyc_data.hist('tripduration_min')
plt.xlabel("Trip Duration (minutes)")
plt.ylabel("Number of Trips")
plt.title("Distribution of NYC Trip Durations")
# plt.savefig('Distribution of NYC Trip Durations.png')

# %%
# Histogram of NYC Trip Durations, zoomed in

nyc_data.hist('tripduration_min', bins=10, range=(0,100))
plt.xlabel("Trip Duration (minutes)")
plt.ylabel("Number of Trips")
plt.title("Distribution of NYC Trip Durations")
plt.savefig('Distribution of NYC Trip Durations.png')

# %%
# Number of unique NYC start stations 

unique_nyc_start_stations = nyc_data['start station name'].unique()
np.count_nonzero(unique_nyc_start_stations)
# Out:
# 527

# %%
# Number of unique NYC stop stations 

unique_nyc_start_stations = nyc_data['start station name'].unique()
np.count_nonzero(unique_nyc_start_stations)
# Out:
# 527

# %%
# Permutation formula = nPk = n! / (n-k)!
# How many ways can you choose 2 stations from a group of 527?
# 527P2 = 527! / 525! = 527 * 526 permutations
# 277,202 permutations of NYC start-stop stations

527* 526
# Out:
# 277202

# %%
# SF

# Creating a new column to change units from seconds to minutes
sf_data['tripduration_min'] = sf_data['tripduration'].map(lambda x: x/60)

# %%
# Average trip time by start station in minutes 
sf_data.groupby(['start station name'], as_index=False).tripduration_min.mean()
# Out:
#                                start station name  tripduration_min
# 0                                   2nd at Folsom          9.695164
# 1                               2nd at South Park         11.464618
# 2                                 2nd at Townsend         13.194416
# 3                                   5th at Howard         15.455710
# 4                                Adobe on Almaden         20.020618
# 5                        Arena Green / SAP Center         32.732799
# 6                                 Beale at Market         14.360890
# 7                       Broadway St at Battery St         13.638542
# 8                                Broadway at Main         41.354229
# 9                 California Ave Caltrain Station         77.133431
# 10               Castro Street and El Camino Real         31.138559
# 11              Civic Center BART (7th at Market)         20.275740
# 12                                Clay at Battery         17.953415
# 13                       Commercial at Montgomery         13.036760
# 14                           Cowper at University         41.287300
# 15                               Davis at Jackson         15.760298
# 16                          Embarcadero at Bryant         16.773799
# 17                          Embarcadero at Folsom         13.847383
# 18                         Embarcadero at Sansome         23.522255
# 19                         Embarcadero at Vallejo         27.236347
# 20                           Evelyn Park and Ride         19.002989
# 21                              Franklin at Maple         28.672098
# 22                            Golden Gate at Polk         19.162031
# 23                Grant Avenue at Columbus Avenue         19.997748
# 24           Harry Bridges Plaza (Ferry Building)         24.916570
# 25                                  Howard at 2nd         12.482888
# 26                                      Japantown         36.796832
# 27                                    MLK Library         25.292011
# 28                                 Market at 10th         17.486911
# 29                                  Market at 4th         21.823571
# ..                                            ...               ...
# 44                    Redwood City Public Library         76.320579
# 45          Rengstorff Avenue / California Street         69.568040
# 46                                    Ryland Park         19.273087
# 47                     SJSU - San Salvador at 9th         22.279882
# 48                         SJSU 4th at San Carlos         32.704672
# 49                   San Antonio Caltrain Station         39.624958
# 50                    San Antonio Shopping Center         38.099688
# 51       San Francisco Caltrain (Townsend at 4th)         13.776118
# 52        San Francisco Caltrain 2 (330 Townsend)         11.502369
# 53                        San Francisco City Hall         29.141257
# 54                             San Jose City Hall         19.782971
# 55                          San Jose Civic Center         70.133616
# 56              San Jose Diridon Caltrain Station         15.424820
# 57                     San Jose Government Center         17.802899
# 58                        San Mateo County Center         45.279501
# 59                               San Pedro Square         23.678871
# 60                            San Salvador at 1st         21.312470
# 61                Santa Clara County Civic Center         25.222123
# 62                         Santa Clara at Almaden         16.097013
# 63                       South Van Ness at Market         40.026722
# 64                                Spear at Folsom         13.149448
# 65                                  St James Park         15.216448
# 66                       Stanford in Redwood City         19.587882
# 67                              Steuart at Market         15.595143
# 68  Temporary Transbay Terminal (Howard at Beale)         10.923919
# 69                                Townsend at 7th         11.275374
# 70                         University and Emerson        118.170657
# 71                          Washington at Kearney         32.988462
# 72                           Washington at Kearny         27.558295
# 73  Yerba Buena Center of the Arts (3rd @ Howard)         15.586126
#
# [74 rows x 2 columns]

# %%
sf_data.tripduration_min.describe()
# Out:
# count    669959.000000
# mean         18.465831
# std         370.923950
# min           1.000000
# 25%           5.733333
# 50%           8.616667
# 75%          12.583333
# max      287840.000000
# Name: tripduration_min, dtype: float64

# %%
# Histogram of SF Trip Durations

sf_data.hist('tripduration_min')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x27ea7e7b8>]], dtype=object)

# %%
sf_data.hist('tripduration_min')
plt.xlim(0,30000)
# Out:
# (0, 30000)

# %%
# Histogram of SF Trip Durations, zoomed in

sf_data.hist('tripduration_min', bins=10, range=(0,100))
plt.xlabel("Trip Duration (minutes)")
plt.ylabel("Number of Trips")
plt.title("Distribution of SF Trip Durations")
plt.savefig('Distribution of SF Trip Durations.png')

# %%
# Number of unique SF start stations 

unique_sf_start_stations = sf_data['start station name'].unique()
np.count_nonzero(unique_sf_start_stations)
# Out:
# 74

# %%
# Number of unique SF stop stations 

unique_sf_start_stations = sf_data['start station name'].unique()
np.count_nonzero(unique_sf_start_stations)
# Out:
# 74

# %%
# Assuming all the start and stop stations are the same
# Permutation formula = nPk = n! / (n-k)!
# How many ways can you choose 2 stations from a group of 74?
# 74P2 = 74! / 72! = 74 * 73 permutations
# 5,402 permutations of SF start-stop stations

74 * 73
# Out:
# 5402

# %% [markdown]
# What is the median trip time?

# %%
# NYC

# Units are in minutes 
nyc_data.groupby(['start station name'], as_index=False).tripduration_min.median()
# Out:
#                                  start station name  tripduration_min
# 0                                   1 Ave & E 15 St          9.166667
# 1                                   1 Ave & E 18 St          9.833333
# 2                                   1 Ave & E 30 St         10.633333
# 3                                   1 Ave & E 44 St         12.050000
# 4                                   1 Ave & E 62 St         10.700000
# 5                                   1 Ave & E 68 St         11.633333
# 6                                   1 Ave & E 78 St         12.433333
# 7                                  10 Ave & W 28 St          9.566667
# 8                                  11 Ave & W 27 St         11.416667
# 9                                  11 Ave & W 41 St         11.950000
# 10                                 11 Ave & W 59 St         17.066667
# 11                                 12 Ave & W 40 St         18.183333
# 12                                  2 Ave & E 31 St          9.883333
# 13                                  2 Ave & E 58 St         13.883333
# 14                                   21 St & 41 Ave         18.933333
# 15                                   21 St & 43 Ave         17.983333
# 16                       21 St & Queens Plaza North         19.950000
# 17                                  3 Ave & E 62 St          9.916667
# 18                                  3 Ave & E 71 St         11.333333
# 19                          3 Ave & Schermerhorn St         10.566667
# 20                              31 St & Thomson Ave         20.058333
# 21   3969.TEMP (Bike The Branches - Central Branch)         27.316667
# 22                              44 Dr & Jackson Ave         11.050000
# 23                                    45 Rd & 11 St          7.583333
# 24                                    46 Ave & 5 St          5.233333
# 25                                   47 Ave & 31 St         12.133333
# 26                                    48 Ave & 5 St         11.050000
# 27                                  5 Ave & E 29 St          8.833333
# 28                                  5 Ave & E 63 St         17.400000
# 29                                  5 Ave & E 73 St         18.800000
# ..                                              ...               ...
# 497                              W 67 St & Broadway         10.616667
# 498                         W 70 St & Amsterdam Ave         10.283333
# 499                          W 74 St & Columbus Ave         11.516667
# 500                          W 76 St & Columbus Ave         12.333333
# 501                              W 78 St & Broadway         13.783333
# 502                     W 82 St & Central Park West         14.916667
# 503                              W 84 St & Broadway         17.583333
# 504                          W 84 St & Columbus Ave         14.316667
# 505                          W Broadway & Spring St         10.950000
# 506                        W Houston St & Hudson St         11.716667
# 507                           Warren St & Church St         10.933333
# 508                     Washington Ave & Greene Ave          7.550000
# 509                       Washington Ave & Park Ave         11.033333
# 510                                 Washington Park          6.050000
# 511                           Washington Pl & 6 Ave          8.916667
# 512                        Washington Pl & Broadway          8.733333
# 513                             Washington Square E          8.650000
# 514                   Washington St & Gansevoort St         12.550000
# 515                         Water - Whitehall Plaza         16.283333
# 516                         Watts St & Greenwich St         11.266667
# 517                           West St & Chambers St         16.200000
# 518                                  West Thames St         14.066667
# 519                            William St & Pine St         11.800000
# 520                        Willoughby Ave & Hall St          8.300000
# 521                   Willoughby Ave & Tompkins Ave         11.916667
# 522                    Willoughby Ave & Walworth St         13.333333
# 523                        Willoughby St & Fleet St          5.966667
# 524                    Wythe Ave & Metropolitan Ave         19.366667
# 525                           Yankee Ferry Terminal         25.291667
# 526                                York St & Jay St         11.083333
#
# [527 rows x 2 columns]

# %%
# SF

# Units are in minutes 
sf_data.groupby(['start station name'], as_index=False).tripduration_min.median()
# Out:
#                                start station name  tripduration_min
# 0                                   2nd at Folsom          5.933333
# 1                               2nd at South Park          7.116667
# 2                                 2nd at Townsend          8.216667
# 3                                   5th at Howard          7.350000
# 4                                Adobe on Almaden          5.566667
# 5                        Arena Green / SAP Center          6.416667
# 6                                 Beale at Market          7.766667
# 7                       Broadway St at Battery St          8.016667
# 8                                Broadway at Main          4.850000
# 9                 California Ave Caltrain Station         17.433333
# 10               Castro Street and El Camino Real          5.066667
# 11              Civic Center BART (7th at Market)          8.466667
# 12                                Clay at Battery          9.416667
# 13                       Commercial at Montgomery          7.391667
# 14                           Cowper at University          4.583333
# 15                               Davis at Jackson          9.550000
# 16                          Embarcadero at Bryant          8.150000
# 17                          Embarcadero at Folsom          8.966667
# 18                         Embarcadero at Sansome         11.066667
# 19                         Embarcadero at Vallejo         11.183333
# 20                           Evelyn Park and Ride          4.483333
# 21                              Franklin at Maple          4.933333
# 22                            Golden Gate at Polk         10.933333
# 23                Grant Avenue at Columbus Avenue          9.116667
# 24           Harry Bridges Plaza (Ferry Building)         10.266667
# 25                                  Howard at 2nd          6.850000
# 26                                      Japantown         12.525000
# 27                                    MLK Library          8.791667
# 28                                 Market at 10th          9.633333
# 29                                  Market at 4th          8.133333
# ..                                            ...               ...
# 44                    Redwood City Public Library          6.650000
# 45          Rengstorff Avenue / California Street         11.133333
# 46                                    Ryland Park          8.633333
# 47                     SJSU - San Salvador at 9th          9.050000
# 48                         SJSU 4th at San Carlos          6.958333
# 49                   San Antonio Caltrain Station          5.366667
# 50                    San Antonio Shopping Center          4.200000
# 51       San Francisco Caltrain (Townsend at 4th)         10.616667
# 52        San Francisco Caltrain 2 (330 Townsend)          9.300000
# 53                        San Francisco City Hall         11.283333
# 54                             San Jose City Hall          7.866667
# 55                          San Jose Civic Center          9.558333
# 56              San Jose Diridon Caltrain Station          7.716667
# 57                     San Jose Government Center         16.783333
# 58                        San Mateo County Center          6.733333
# 59                               San Pedro Square          6.866667
# 60                            San Salvador at 1st          6.841667
# 61                Santa Clara County Civic Center         12.483333
# 62                         Santa Clara at Almaden          4.583333
# 63                       South Van Ness at Market         11.116667
# 64                                Spear at Folsom          8.133333
# 65                                  St James Park          7.275000
# 66                       Stanford in Redwood City         13.783333
# 67                              Steuart at Market          8.916667
# 68  Temporary Transbay Terminal (Howard at Beale)          8.200000
# 69                                Townsend at 7th          8.450000
# 70                         University and Emerson         45.983333
# 71                          Washington at Kearney         11.358333
# 72                           Washington at Kearny         10.750000
# 73  Yerba Buena Center of the Arts (3rd @ Howard)          7.300000
#
# [74 rows x 2 columns]

# %% [markdown]
# What is the range of trip times?

# %%
# NYC
nyc_data.tripduration_min.describe()
# Out:
# count    2.873239e+07
# mean     1.545412e+01
# std      1.096158e+02
# min      1.000000e+00
# 25%      6.483333e+00
# 50%      1.043333e+01
# 75%      1.735000e+01
# max      1.041792e+05
# Name: tripduration_min, dtype: float64

# %%
# Units are in minutes
nyc_data.groupby(['start station name']).tripduration_min.describe()
# Out:
# start station name
# 1 Ave & E 15 St               count    154640.000000
#                               mean         12.785604
#                               std         101.063540
#                               min           1.000000
#                               25%           5.500000
#                               50%           9.166667
#                               75%          14.266667
#                               max       23224.400000
# 1 Ave & E 18 St               count     85445.000000
#                               mean         13.089510
#                               std          50.547398
#                               min           1.000000
#                               25%           6.216667
#                               50%           9.833333
#                               75%          15.133333
#                               max        9836.600000
# 1 Ave & E 30 St               count    111145.000000
#                               mean         13.530626
#                               std          47.384964
#                               min           1.000000
#                               25%           7.466667
#                               50%          10.633333
#                               75%          15.200000
#                               max        9076.766667
# 1 Ave & E 44 St               count     67997.000000
#                               mean         15.555993
#                               std          33.835083
#                               min           1.000000
#                               25%           7.616667
#                               50%          12.050000
#                                            ...
# Willoughby St & Fleet St      std         165.777984
#                               min           1.000000
#                               25%           4.550000
#                               50%           5.966667
#                               75%           8.683333
#                               max       26118.333333
# Wythe Ave & Metropolitan Ave  count     55291.000000
#                               mean         24.237537
#                               std         199.690588
#                               min           1.000000
#                               25%           8.216667
#                               50%          19.366667
#                               75%          26.533333
#                               max       38802.350000
# Yankee Ferry Terminal         count      3736.000000
#                               mean         43.588169
#                               std         199.695894
#                               min           1.016667
#                               25%          18.029167
#                               50%          25.291667
#                               75%          34.783333
#                               max        5831.683333
# York St & Jay St              count     56744.000000
#                               mean         18.161541
#                               std         177.091630
#                               min           1.000000
#                               25%           6.366667
#                               50%          11.083333
#                               75%          18.633333
#                               max       30010.000000
# Name: tripduration_min, dtype: float64

# %%
# Boxplot of NYC Trip Durations

nyc_data.boxplot('tripduration_min')
plt.ylabel('Trip Duration (minutes)')
# Out:
# /Users/andrewlam/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':

# %%
# Boxplot of NYC Trip Durations, zoomed in

nyc_data.boxplot('tripduration_min')
plt.ylabel('Trip Duration (minutes)')
plt.ylim(0,30)
plt.title("Box Plot of NYC Trip Durations")
plt.savefig('Box Plot of NYC Trip Durations.png')
# Out:
# /Users/andrewlam/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':

# %%
# SF

# Units are in minutes
sf_data.tripduration_min.describe()
# Out:
# count    669959.000000
# mean         18.465831
# std         370.923950
# min           1.000000
# 25%           5.733333
# 50%           8.616667
# 75%          12.583333
# max      287840.000000
# Name: tripduration_min, dtype: float64

# %%
# Units are in minutes
sf_data.groupby(['start station name']).tripduration_min.describe()
# Out:
# start station name
# 2nd at Folsom                                  count    15940.000000
#                                                mean         9.695164
#                                                std         48.203030
#                                                min          1.016667
#                                                25%          3.950000
#                                                50%          5.933333
#                                                75%          8.266667
#                                                max       4670.466667
# 2nd at South Park                              count    18496.000000
#                                                mean        11.464618
#                                                std         40.731020
#                                                min          1.000000
#                                                25%          5.083333
#                                                50%          7.116667
#                                                75%         10.550000
#                                                max       1503.550000
# 2nd at Townsend                                count    25837.000000
#                                                mean        13.194416
#                                                std         52.818300
#                                                min          1.000000
#                                                25%          6.383333
#                                                50%          8.216667
#                                                75%         11.183333
#                                                max       3493.633333
# 5th at Howard                                  count    13526.000000
#                                                mean        15.455710
#                                                std         68.297730
#                                                min          1.050000
#                                                25%          5.766667
#                                                50%          7.350000
#                                                             ...
# University and Emerson                         std        671.890938
#                                                min          1.050000
#                                                25%         17.050000
#                                                50%         45.983333
#                                                75%         87.608333
#                                                max      18892.333333
# Washington at Kearney                          count     1472.000000
#                                                mean        32.988462
#                                                std        103.459774
#                                                min          1.083333
#                                                25%          7.429167
#                                                50%         11.358333
#                                                75%         18.879167
#                                                max       1474.733333
# Washington at Kearny                           count     4292.000000
#                                                mean        27.558295
#                                                std         79.035560
#                                                min          1.083333
#                                                25%          7.283333
#                                                50%         10.750000
#                                                75%         18.354167
#                                                max       1893.700000
# Yerba Buena Center of the Arts (3rd @ Howard)  count    11251.000000
#                                                mean        15.586126
#                                                std         59.513017
#                                                min          1.000000
#                                                25%          5.450000
#                                                50%          7.300000
#                                                75%         10.400000
#                                                max       2582.983333
# Name: tripduration_min, dtype: float64

# %%
# Boxplot of SF Trip Durations

sf_data.boxplot('tripduration_min')
plt.ylabel('Trip Duration (minutes)')
# Out:
# /Users/andrewlam/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   app.launch_new_instance()

# %%
# Boxplot of SF Trip Durations
# Changing y axis to remove outliers and improve readability of the interquartile range 

sf_data.boxplot('tripduration_min')
plt.ylabel('Trip Duration (minutes)')
plt.ylim(0,30)
plt.title("Box Plot of SF Trip Durations")
plt.savefig('Box Plot of SF Trip Durations.png')
# Out:
# /Users/andrewlam/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   app.launch_new_instance()

# %% [markdown]
# What is the standard deviation of trip times?

# %%
# See output from describe() above for information on standard deviation
